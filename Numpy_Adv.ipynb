# %%
import numpy as np

# %%
arr = np.array([0])

# %%
np.sin(np.deg2rad(arr))
# Out:
# array([0.])

# %%
arr = np.array([0, 45, 90, 180, 270, 360])

# %%
np.sin(np.deg2rad(arr))
# Out:
# array([ 0.00000000e+00,  7.07106781e-01,  1.00000000e+00,  1.22464680e-16,
#        -1.00000000e+00, -2.44929360e-16])

# %%
np.sin(arr)
# Out:
# array([ 0.        ,  0.85090352,  0.89399666, -0.80115264, -0.17604595,
#         0.95891572])

# %%
np.cos(np.deg2rad(arr))
# Out:
# array([ 1.00000000e+00,  7.07106781e-01,  6.12323400e-17, -1.00000000e+00,
#        -1.83697020e-16,  1.00000000e+00])

# %%
np.arccos(0.5)
# Out:
# 1.0471975511965979

# %%
np.array(['a', 0.50, 4]).dtype
# Out:
# dtype('<U3')

# %%
np.array(['a']).dtype
# Out:
# dtype('<U1')

# %%
np.array([0.5, 4]).dtype
# Out:
# dtype('float64')

# %%
np.array([40000, 45000]).dtype
# Out:
# dtype('int32')

# %%
arr = np.array(list(np.arange(10, 100, 10)))

# %%
arr
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
arr.mean()
# Out:
# 50.0

# %%
arr.std()
# Out:
# 25.81988897471611

# %%
np.median(arr)
# Out:
# 50.0

# %%
np.exp(arr)
# Out:
# array([2.20264658e+04, 4.85165195e+08, 1.06864746e+13, 2.35385267e+17,
#        5.18470553e+21, 1.14200739e+26, 2.51543867e+30, 5.54062238e+34,
#        1.22040329e+39])

# %%
np.log(arr)
# Out:
# array([2.30258509, 2.99573227, 3.40119738, 3.68887945, 3.91202301,
#        4.09434456, 4.24849524, 4.38202663, 4.49980967])

# %%
np.log10(arr)
# Out:
# array([1.        , 1.30103   , 1.47712125, 1.60205999, 1.69897   ,
#        1.77815125, 1.84509804, 1.90308999, 1.95424251])

# %% [markdown]
# # Aggregate Function

# %%
heights = np.array([150, 189, 165, 160])

# %%
heights
# Out:
# array([150, 189, 165, 160])

# %%
heights.mean()
# Out:
# 166.0

# %%
np.median(heights)
# Out:
# 162.5

# %%
arr
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
len(arr)
# Out:
# 9

# %%
arr[1]
# Out:
# 20

# %%
arr[[0]]
# Out:
# array([10])

# %%
arr[[0, 1]:8]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-a1ce6f7eab81> in <module>
# ----> 1 arr[[0, 1]:8]
#
# TypeError: slice indices must be integers or None or have an __index__ method

# %%
arr[-1]
# Out:
# 90

# %%
arr[::2]
# Out:
# array([10, 30, 50, 70, 90])

# %%
arr[::3]
# Out:
# array([10, 40, 70])

# %%
arr[::-1]
# Out:
# array([90, 80, 70, 60, 50, 40, 30, 20, 10])

# %%
arr
# Out:
# array([10, 20, 30, 40, 50, 60, 70, 80, 90])

# %%
arr2d = [[i, j, k] for i in range(0, 100, 10) for j in range(110, 200, 10) for k in range(200, 300, 10)]

# %%
arr2d
# Out:
# [[0, 110, 200],
#  [0, 110, 210],
#  [0, 110, 220],
#  [0, 110, 230],
#  [0, 110, 240],
#  [0, 110, 250],
#  [0, 110, 260],
#  [0, 110, 270],
#  [0, 110, 280],
#  [0, 110, 290],
#  [0, 120, 200],
#  [0, 120, 210],
#  [0, 120, 220],
#  [0, 120, 230],
#  [0, 120, 240],
#  [0, 120, 250],
#  [0, 120, 260],
#  [0, 120, 270],
#  [0, 120, 280],
#  [0, 120, 290],
#  [0, 130, 200],
#  [0, 130, 210],
#  [0, 130, 220],
#  [0, 130, 230],
#  [0, 130, 240],
#  [0, 130, 250],
#  [0, 130, 260],
#  [0, 130, 270],
#  [0, 130, 280],
#  [0, 130, 290],
#  [0, 140, 200],
#  [0, 140, 210],
#  [0, 140, 220],
#  [0, 140, 230],
#  [0, 140, 240],
#  [0, 140, 250],
#  [0, 140, 260],
#  [0, 140, 270],
#  [0, 140, 280],
#  [0, 140, 290],
#  [0, 150, 200],
#  [0, 150, 210],
#  [0, 150, 220],
#  [0, 150, 230],
#  [0, 150, 240],
#  [0, 150, 250],
#  [0, 150, 260],
#  [0, 150, 270],
#  [0, 150, 280],
#  [0, 150, 290],
#  [0, 160, 200],
#  [0, 160, 210],
#  [0, 160, 220],
#  [0, 160, 230],
#  [0, 160, 240],
# ...

# %%
arr2d = [[10, 20, 30], [40, 50, 60], [70, 80, 90]]

# %%
arr2d = np.array(arr2d)
arr2d
# Out:
# array([[10, 20, 30],
#        [40, 50, 60],
#        [70, 80, 90]])

# %%
arr2d.ndim
# Out:
# 2

# %%
arr2d[[1,2], [,]]
# Out:
#   File "<ipython-input-53-a6f9269d48be>", line 1
#     arr2d[[1,2], [,]]
#                   ^
# SyntaxError: invalid syntax
